# %%
import requests
import json
response_API = requests.get('https://covid-19.nchc.org.tw/api/covid19?CK=covid-19@nchc.org.tw&querydata=3001&limited=TWN')
#print(response_API.status_code)

# %%
data = response_API.text
datajson = json.loads(data)

datajson
# Out:
# [{'id': '157006',
#   'a01': 'TWN',
#   'a02': '亞洲',
#   'a03': '台灣',
#   'a04': '2022-05-28',
#   'a05': '1815703',
#   'a06': '80636',
#   'a07': '82115.143',
#   'a08': '1947',
#   'a09': '163',
#   'a10': '86.286',
#   'a11': '76114.122',
#   'a12': '81.618',
#   'a13': '0.000',
#   'a14': '0',
#   'a15': '0',
#   'a16': '0.000',
#   'a17': '0.000',
#   'a18': '0.000',
#   'a19': '0.000',
#   'a20': '0',
#   'a21': '0',
#   'a22': '0',
#   'a23': '0.000',
#   'a24': '0.000',
#   'a25': '0.000',
#   'a26': '0.000',
#   'a27': '23855008',
#   'a28': '42.200',
#   'a29': '8.353',
#   'a30': '80.460',
#   'a31': '14835',
#   'a32': '121.52'},
#  {'id': '157005',
#   'a01': 'TWN',
#   'a02': '亞洲',
#   'a03': '台灣',
#   'a04': '2022-05-27',
#   'a05': '1735067',
#   'a06': '94796',
#   'a07': '82682.286',
#   'a08': '1784',
#   'a09': '126',
#   'a10': '71.429',
#   'a11': '72733.868',
#   'a12': '74.785',
#   'a13': '0.000',
#   'a14': '0',
#   'a15': '0',
#   'a16': '0.000',
# ...
